# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
with open('./code-600000-600100.pkl', 'rb') as f:
    results = pickle.load(f)

# %%
is_profit = [p[-1] for p in results]
len(is_profit)
# Out:
# 79

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font = fm.FontProperties(fname='./font/wqy-microhei.ttc')

labels = 'Profit', 'Loss', '0'

sizes = [0, 0, 0]

for p in is_profit:
    if p > 0:
        sizes[0] += 1
    if p < 0:
        sizes[1] += 1
    else:
        sizes[2] += 1

explode = (0.1, 0.05, 0.05)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', 
        shadow=True, startangle=90)
ax1.axis('equal')
plt.legend(prop=font)
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font = fm.FontProperties(fname='./font/wqy-microhei.ttc')
n_bins = 20

fig, axs = plt.subplots()
axs.hist(is_profit, bins=n_bins, density=True)
# Out:
# (array([0.0001553 , 0.        , 0.0001553 , 0.        , 0.0006212 ,
#         0.0004659 , 0.00155299, 0.00170829, 0.00124239, 0.00077649,
#         0.00108709, 0.00124239, 0.00124239, 0.0006212 , 0.0003106 ,
#         0.0001553 , 0.0006212 , 0.0001553 , 0.        , 0.0001553 ]),
#  array([-499.10593729, -417.59717433, -336.08841136, -254.5796484 ,
#         -173.07088543,  -91.56212247,  -10.05335951,   71.45540346,
#          152.96416642,  234.47292939,  315.98169235,  397.49045531,
#          478.99921828,  560.50798124,  642.01674421,  723.52550717,
#          805.03427013,  886.5430331 ,  968.05179606, 1049.56055902,
#         1131.06932199]),
#  <a list of 20 Patch objects>)
